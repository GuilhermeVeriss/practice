# %% [markdown]
# <a href="https://colab.research.google.com/github/GuilhermeVeriss/practice/blob/main/python_learn/numpy_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **NUMPY TUTORIAL NOTEBOOK**
#
# This notebook was created to practice some code about numpy with the tutorial from Mr. P Solver, on Youtube.
#
# The video URL is the following: https://www.youtube.com/watch?v=DcfYgePyedM&t=24s

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # **Basics 1D arrays**

# %% [markdown]
# # **Question 1**

# %%
#1

x = np.linspace(0, 10, 10001)
y = np.exp(-x/10) * np.sin(x)
plt.plot(x, y)

# %%
#2

y_interval_4to7 = y[(4 <= x) & (x <= 7)]
y_mean = np.mean(y_interval_4to7)
y_std = np.std(y_interval_4to7)
print(f"Mean: {y_mean}, std: {y_std}")
# Out:
# Mean: -0.2956023068963138, std: 0.31448753875085117

# %%
#3

np.percentile(y_interval_4to7, 80)
# Out:
# 0.06145551274590662

# %%
#4

dydx = np.gradient(y, x)
plt.plot(x, y)
plt.plot(x, dydx)

# %%
#5
x[1:][dydx[1:] * dydx[:-1] < 0]
# Out:
# array([1.472, 4.613, 7.755])

# %% [markdown]
# #**Question 2**

# %%
x1 = np.arange(0, 10001)
np.sum(x1[(x1%4!=0) * (x1%7!=0)])
# Out:
# 32147142

# %% [markdown]
# #**Question 3**

# %%
#1

theta = np.linspace(0, 2*np.pi, 10001)
r = 1 + (3/4) * np.sin(3*theta)
x = r * np.cos(theta)
y = r * np.sin(theta)

plt.plot(x, y)

# %%
#2 

0.5 * np.sum(r**2) * (theta[1]-theta[0])
# Out:
# 4.025479746677282

# %%
#3
np.sum((r**2 + (np.gradient(r, theta))**2)**(1/2)) * (theta[1]-theta[0])
# Out:
# 11.626531059700874

# %% [markdown]
# #**Question 4**

# %%
t = np.linspace(0, 100, 10000)
To = 10**5
T = To * (1/(1+ np.exp(-0.1*t)))

plt.plot(t, T)

# Not finished!!!!!!!

# %% [markdown]
# # **Multi-dimensional arrays**

# %% [markdown]
# # **Question 1**

# %%
#1 
x = np.linspace(-2, 2, 10000)
y = np.linspace(-2, 2, 10000)

xv, yv = np.meshgrid(x, y)
f = np.exp(-(xv**2 + yv**2)) * np.sin(xv)

plt.contourf(xv, yv, f, levels=50)
plt.colorbar()

# %%
np.sum(abs(f)) * np.diff(x)[0] * np.diff(y)[0]
# Out:
# 1.4860224966230566

# %%
np.sum(abs(f[xv**2 + yv**2 > 0.25])) * np.diff(x)[0] * np.diff(y)[0]
# Out:
# 1.3445714965595938
